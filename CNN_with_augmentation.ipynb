# %%
from tensorflow import keras
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import glob 
import numpy as np
from os import listdir,makedirs
from os.path import isfile,join
from numpy import *
from PIL import Image
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import random
import cv2
import os
# Out:
# Using TensorFlow backend.

# %%
path_2="/home/dashan/Desktop/modified_data"

IMG_SIZE=300

def label_img(name):
	if name[0:2]=="no":
		return np.array([1,0])
	elif name[0:2]=="ca":
		return np.array([0,1])

def load_training_data(arg):
	train_data=[]
	DIR=path_2+"/"+arg
	for img in os.listdir(DIR):
		label=label_img(img)
		path=os.path.join(DIR,img)
		img=Image.open(path)
		img=img.convert('L')
		img.resize((IMG_SIZE,IMG_SIZE),Image.ANTIALIAS)
		train_data.append([np.array(img),label])
	shuffle(train_data)
	return train_data
a=load_training_data("1_normal")
b=load_training_data("2_cataract")

# %%
print(len(a),len(b))
train_data=[]
for i in a:
	train_data.append(i)
shuffle(train_data)
for i in b:
	train_data.append(i)
# Out:
# 2000 2000

# %%
trainImages = np.array([i[0] for i in train_data]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
trainLabels = np.array([i[1] for i in train_data])

# %%
from keras.models import Sequential
from keras import regularizers
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.layers.normalization import BatchNormalization

# IMG_SIZE=300
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1),kernel_regularizer=regularizers.l2(0.01)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3), activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3), activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(96, kernel_size=(3,3), activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size=(3,3), activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Flatten())
# model.add(Dense(512, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
# model.add(Dropout(0.3))
model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.3))
model.add(Dense(2, activation = 'softmax'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
print("compile to ho gya ")
model.summary()
# Out:
# compile to ho gya
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 298, 298, 32)      320
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 149, 149, 32)      0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 149, 149, 32)      128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 147, 147, 64)      18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 73, 73, 64)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 73, 73, 64)        256
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 71, 71, 64)        36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 35, 35, 64)        256
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 33, 33, 96)        55392
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 16, 96)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 16, 96)        384
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 32)        27680
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 7, 7, 32)          128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               401664
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 574,786
# Trainable params: 574,210
# Non-trainable params: 576
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(trainImages, trainLabels, test_size=0.125,random_state=1234)

# %%
history = model.fit(trainX, trainY,
                    batch_size=10,
                    epochs=100,
                    # We pass some validation for
                    # monitoring validation loss and metrics
                    # at the end of each epoch
                    validation_data=(testX,testY),verbose=1)
# Out:
# Train on 3500 samples, validate on 500 samples
# Epoch 1/100
# 3500/3500 [==============================] - 475s 136ms/step - loss: 4.8130 - accuracy: 0.6137 - val_loss: 2.7337 - val_accuracy: 0.4920
# Epoch 2/100
# 3500/3500 [==============================] - 399s 114ms/step - loss: 1.5899 - accuracy: 0.7506 - val_loss: 1.1359 - val_accuracy: 0.7660
# Epoch 3/100
# 3500/3500 [==============================] - 365s 104ms/step - loss: 0.9196 - accuracy: 0.8009 - val_loss: 0.8588 - val_accuracy: 0.6960
# Epoch 4/100
# 3500/3500 [==============================] - 367s 105ms/step - loss: 0.7164 - accuracy: 0.8111 - val_loss: 1.0273 - val_accuracy: 0.6100
# Epoch 5/100
# 3500/3500 [==============================] - 367s 105ms/step - loss: 0.6211 - accuracy: 0.8320 - val_loss: 0.6233 - val_accuracy: 0.8340
# Epoch 6/100
# 3500/3500 [==============================] - 367s 105ms/step - loss: 0.5725 - accuracy: 0.8394 - val_loss: 0.9181 - val_accuracy: 0.6300
# Epoch 7/100
# 3500/3500 [==============================] - 367s 105ms/step - loss: 0.5349 - accuracy: 0.8414 - val_loss: 0.5327 - val_accuracy: 0.8460
# Epoch 8/100
# 3500/3500 [==============================] - 367s 105ms/step - loss: 0.5435 - accuracy: 0.8437 - val_loss: 1.9059 - val_accuracy: 0.5520
# Epoch 9/100
# 3500/3500 [==============================] - 368s 105ms/step - loss: 0.5634 - accuracy: 0.8434 - val_loss: 0.9072 - val_accuracy: 0.6700
# Epoch 10/100
# 3500/3500 [==============================] - 367s 105ms/step - loss: 0.5452 - accuracy: 0.8346 - val_loss: 0.5369 - val_accuracy: 0.8460
# Epoch 11/100
# 3500/3500 [==============================] - 370s 106ms/step - loss: 0.5230 - accuracy: 0.8374 - val_loss: 0.6184 - val_accuracy: 0.7900
# Epoch 12/100
# 3500/3500 [==============================] - 399s 114ms/step - loss: 0.4921 - accuracy: 0.8523 - val_loss: 0.4552 - val_accuracy: 0.8640
# Epoch 13/100
# 3500/3500 [==============================] - 423s 121ms/step - loss: 0.4797 - accuracy: 0.8614 - val_loss: 0.5539 - val_accuracy: 0.8320
# Epoch 14/100
# 3500/3500 [==============================] - 441s 126ms/step - loss: 0.4979 - accuracy: 0.8506 - val_loss: 0.7384 - val_accuracy: 0.7140
# Epoch 15/100
# 3500/3500 [==============================] - 439s 125ms/step - loss: 0.4694 - accuracy: 0.8617 - val_loss: 2.4393 - val_accuracy: 0.4940
# Epoch 16/100
# 3500/3500 [==============================] - 440s 126ms/step - loss: 0.4988 - accuracy: 0.8506 - val_loss: 0.4651 - val_accuracy: 0.8560
# Epoch 17/100
# 3500/3500 [==============================] - 441s 126ms/step - loss: 0.4791 - accuracy: 0.8557 - val_loss: 0.5189 - val_accuracy: 0.8420
# Epoch 18/100
# 3500/3500 [==============================] - 440s 126ms/step - loss: 0.4599 - accuracy: 0.8600 - val_loss: 0.7443 - val_accuracy: 0.7020
# Epoch 19/100
# 3500/3500 [==============================] - 442s 126ms/step - loss: 0.4673 - accuracy: 0.8574 - val_loss: 0.6033 - val_accuracy: 0.7540
# Epoch 20/100
# 3500/3500 [==============================] - 444s 127ms/step - loss: 0.4802 - accuracy: 0.8560 - val_loss: 0.4685 - val_accuracy: 0.8600
# Epoch 21/100
# 3500/3500 [==============================] - 443s 126ms/step - loss: 0.4603 - accuracy: 0.8634 - val_loss: 0.6034 - val_accuracy: 0.7980
# Epoch 22/100
# 3500/3500 [==============================] - 441s 126ms/step - loss: 0.4505 - accuracy: 0.8657 - val_loss: 0.4607 - val_accuracy: 0.8540
# Epoch 23/100
# 3500/3500 [==============================] - 442s 126ms/step - loss: 0.4302 - accuracy: 0.8689 - val_loss: 0.4166 - val_accuracy: 0.8660
# Epoch 24/100
# 3500/3500 [==============================] - 440s 126ms/step - loss: 0.4178 - accuracy: 0.8763 - val_loss: 0.5187 - val_accuracy: 0.8540
# Epoch 25/100
# 3500/3500 [==============================] - 444s 127ms/step - loss: 0.4313 - accuracy: 0.8731 - val_loss: 0.4161 - val_accuracy: 0.8680
# Epoch 26/100
# 3500/3500 [==============================] - 439s 125ms/step - loss: 0.4162 - accuracy: 0.8751 - val_loss: 0.4606 - val_accuracy: 0.8540
# Epoch 27/100
# 3500/3500 [==============================] - 440s 126ms/step - loss: 0.4309 - accuracy: 0.8674 - val_loss: 0.4249 - val_accuracy: 0.8620
# Epoch 28/100
# 3500/3500 [==============================] - 443s 127ms/step - loss: 0.4166 - accuracy: 0.8771 - val_loss: 0.4143 - val_accuracy: 0.8680
# Epoch 29/100
# 3500/3500 [==============================] - 440s 126ms/step - loss: 0.4073 - accuracy: 0.8840 - val_loss: 0.4983 - val_accuracy: 0.8560
# Epoch 30/100
# 3500/3500 [==============================] - 442s 126ms/step - loss: 0.4115 - accuracy: 0.8834 - val_loss: 0.7057 - val_accuracy: 0.7500
# Epoch 31/100
# 3500/3500 [==============================] - 438s 125ms/step - loss: 0.4076 - accuracy: 0.8869 - val_loss: 0.4365 - val_accuracy: 0.8700
# Epoch 32/100
# 3500/3500 [==============================] - 442s 126ms/step - loss: 0.4010 - accuracy: 0.8883 - val_loss: 0.4515 - val_accuracy: 0.8760
# Epoch 33/100
# 3500/3500 [==============================] - 442s 126ms/step - loss: 0.4182 - accuracy: 0.8854 - val_loss: 0.4274 - val_accuracy: 0.8740
# Epoch 34/100
# 3500/3500 [==============================] - 461s 132ms/step - loss: 0.4106 - accuracy: 0.8857 - val_loss: 0.5782 - val_accuracy: 0.8240
# Epoch 35/100
# 3500/3500 [==============================] - 432s 123ms/step - loss: 0.4135 - accuracy: 0.8934 - val_loss: 0.4287 - val_accuracy: 0.8800
# Epoch 36/100
# 3500/3500 [==============================] - 435s 124ms/step - loss: 0.3952 - accuracy: 0.8974 - val_loss: 0.4638 - val_accuracy: 0.8540
# Epoch 37/100
# 3500/3500 [==============================] - 373s 107ms/step - loss: 0.3967 - accuracy: 0.8989 - val_loss: 0.4025 - val_accuracy: 0.8940
# Epoch 38/100
# 3500/3500 [==============================] - 372s 106ms/step - loss: 0.3990 - accuracy: 0.8983 - val_loss: 0.4095 - val_accuracy: 0.8780
# Epoch 39/100
# 3500/3500 [==============================] - 373s 107ms/step - loss: 0.3763 - accuracy: 0.9071 - val_loss: 0.4229 - val_accuracy: 0.8800
# Epoch 40/100
# 3500/3500 [==============================] - 444s 127ms/step - loss: 0.3802 - accuracy: 0.9120 - val_loss: 0.4007 - val_accuracy: 0.8860
# Epoch 41/100
# 3500/3500 [==============================] - 422s 121ms/step - loss: 0.3783 - accuracy: 0.9106 - val_loss: 0.3997 - val_accuracy: 0.8940
# Epoch 42/100
# 3500/3500 [==============================] - 465s 133ms/step - loss: 0.3828 - accuracy: 0.9074 - val_loss: 0.4058 - val_accuracy: 0.9080
# Epoch 43/100
# 3500/3500 [==============================] - 364s 104ms/step - loss: 0.3963 - accuracy: 0.9040 - val_loss: 0.4385 - val_accuracy: 0.8820
# Epoch 44/100
# 3500/3500 [==============================] - 431s 123ms/step - loss: 0.3886 - accuracy: 0.9023 - val_loss: 0.4679 - val_accuracy: 0.8680
# Epoch 45/100
# 3500/3500 [==============================] - 472s 135ms/step - loss: 0.3767 - accuracy: 0.9137 - val_loss: 0.4502 - val_accuracy: 0.8620
# Epoch 46/100
# 3500/3500 [==============================] - 451s 129ms/step - loss: 0.3805 - accuracy: 0.9137 - val_loss: 0.4300 - val_accuracy: 0.8900
# Epoch 47/100
# 3500/3500 [==============================] - 439s 125ms/step - loss: 0.3773 - accuracy: 0.9174 - val_loss: 0.4840 - val_accuracy: 0.8540
# Epoch 48/100
# 3500/3500 [==============================] - 447s 128ms/step - loss: 0.3600 - accuracy: 0.9223 - val_loss: 0.4692 - val_accuracy: 0.8960
# Epoch 49/100
# 3500/3500 [==============================] - 375s 107ms/step - loss: 0.3764 - accuracy: 0.9191 - val_loss: 0.4346 - val_accuracy: 0.8880
# Epoch 50/100
# 3500/3500 [==============================] - 370s 106ms/step - loss: 0.3582 - accuracy: 0.9260 - val_loss: 0.4833 - val_accuracy: 0.8780
# Epoch 51/100
# 3500/3500 [==============================] - 371s 106ms/step - loss: 0.3531 - accuracy: 0.9283 - val_loss: 0.4114 - val_accuracy: 0.9040
# Epoch 52/100
# 3500/3500 [==============================] - 369s 105ms/step - loss: 0.3504 - accuracy: 0.9294 - val_loss: 0.4351 - val_accuracy: 0.8880
# Epoch 53/100
# 3500/3500 [==============================] - 369s 105ms/step - loss: 0.3536 - accuracy: 0.9300 - val_loss: 0.5089 - val_accuracy: 0.8620
# Epoch 54/100
# 3500/3500 [==============================] - 370s 106ms/step - loss: 0.3530 - accuracy: 0.9263 - val_loss: 0.4517 - val_accuracy: 0.8840
# Epoch 55/100
# 3500/3500 [==============================] - 363s 104ms/step - loss: 0.3475 - accuracy: 0.9329 - val_loss: 0.4800 - val_accuracy: 0.8820
# Epoch 56/100
# 3500/3500 [==============================] - 364s 104ms/step - loss: 0.3530 - accuracy: 0.9306 - val_loss: 0.4434 - val_accuracy: 0.9020
# Epoch 57/100
# 3500/3500 [==============================] - 367s 105ms/step - loss: 0.3409 - accuracy: 0.9371 - val_loss: 0.4281 - val_accuracy: 0.8900
# Epoch 58/100
# 3500/3500 [==============================] - 365s 104ms/step - loss: 0.3403 - accuracy: 0.9360 - val_loss: 0.4736 - val_accuracy: 0.8720
# Epoch 59/100
# 3500/3500 [==============================] - 366s 105ms/step - loss: 0.3573 - accuracy: 0.9351 - val_loss: 0.4095 - val_accuracy: 0.9120
# Epoch 60/100
# 3500/3500 [==============================] - 366s 105ms/step - loss: 0.3374 - accuracy: 0.9409 - val_loss: 0.4730 - val_accuracy: 0.8880
# Epoch 61/100
# 3500/3500 [==============================] - 366s 105ms/step - loss: 0.3347 - accuracy: 0.9449 - val_loss: 0.4462 - val_accuracy: 0.9020
# Epoch 62/100
# 3500/3500 [==============================] - 375s 107ms/step - loss: 0.3448 - accuracy: 0.9380 - val_loss: 0.4265 - val_accuracy: 0.8920
# Epoch 63/100
# 3500/3500 [==============================] - 367s 105ms/step - loss: 0.3508 - accuracy: 0.9360 - val_loss: 0.4315 - val_accuracy: 0.9040
# Epoch 64/100
# 3500/3500 [==============================] - 362s 104ms/step - loss: 0.3397 - accuracy: 0.9414 - val_loss: 0.4116 - val_accuracy: 0.9160
# Epoch 65/100
# 3500/3500 [==============================] - 362s 103ms/step - loss: 0.3393 - accuracy: 0.9411 - val_loss: 0.4278 - val_accuracy: 0.9060
# Epoch 66/100
# 3500/3500 [==============================] - 365s 104ms/step - loss: 0.3276 - accuracy: 0.9471 - val_loss: 0.4066 - val_accuracy: 0.9080
# Epoch 67/100
# 3500/3500 [==============================] - 362s 103ms/step - loss: 0.3339 - accuracy: 0.9434 - val_loss: 0.4501 - val_accuracy: 0.9080
# Epoch 68/100
# 3500/3500 [==============================] - 360s 103ms/step - loss: 0.3268 - accuracy: 0.9469 - val_loss: 0.4522 - val_accuracy: 0.8880
# Epoch 69/100
# 3500/3500 [==============================] - 362s 104ms/step - loss: 0.3486 - accuracy: 0.9391 - val_loss: 0.4146 - val_accuracy: 0.9120
# Epoch 70/100
# 3500/3500 [==============================] - 372s 106ms/step - loss: 0.3313 - accuracy: 0.9420 - val_loss: 0.4750 - val_accuracy: 0.8920
# Epoch 71/100
# 3500/3500 [==============================] - 372s 106ms/step - loss: 0.3433 - accuracy: 0.9417 - val_loss: 0.4531 - val_accuracy: 0.9080
# Epoch 72/100
# 3500/3500 [==============================] - 373s 106ms/step - loss: 0.3386 - accuracy: 0.9440 - val_loss: 0.4753 - val_accuracy: 0.9000
# Epoch 73/100
# 3500/3500 [==============================] - 432s 123ms/step - loss: 0.3351 - accuracy: 0.9466 - val_loss: 0.4459 - val_accuracy: 0.9100
# Epoch 74/100
# 3500/3500 [==============================] - 449s 128ms/step - loss: 0.3334 - accuracy: 0.9420 - val_loss: 0.4280 - val_accuracy: 0.9100
# Epoch 75/100
# 3500/3500 [==============================] - 472s 135ms/step - loss: 0.3386 - accuracy: 0.9451 - val_loss: 0.4430 - val_accuracy: 0.9020
# Epoch 76/100
# 3500/3500 [==============================] - 465s 133ms/step - loss: 0.3361 - accuracy: 0.9431 - val_loss: 0.4197 - val_accuracy: 0.8980
# Epoch 77/100
# 3500/3500 [==============================] - 456s 130ms/step - loss: 0.3275 - accuracy: 0.9497 - val_loss: 0.3887 - val_accuracy: 0.9300
# Epoch 78/100
# 3500/3500 [==============================] - 460s 131ms/step - loss: 0.3181 - accuracy: 0.9469 - val_loss: 0.4539 - val_accuracy: 0.9020
# Epoch 79/100
# 3500/3500 [==============================] - 465s 133ms/step - loss: 0.3176 - accuracy: 0.9469 - val_loss: 0.4162 - val_accuracy: 0.9100
# Epoch 80/100
# 3500/3500 [==============================] - 463s 132ms/step - loss: 0.3328 - accuracy: 0.9429 - val_loss: 0.4607 - val_accuracy: 0.8900
# Epoch 81/100
# 3500/3500 [==============================] - 463s 132ms/step - loss: 0.3203 - accuracy: 0.9534 - val_loss: 0.4462 - val_accuracy: 0.8960
# Epoch 82/100
# 3500/3500 [==============================] - 460s 132ms/step - loss: 0.3255 - accuracy: 0.9466 - val_loss: 0.4352 - val_accuracy: 0.9060
# Epoch 83/100
# 3500/3500 [==============================] - 462s 132ms/step - loss: 0.3250 - accuracy: 0.9497 - val_loss: 0.4025 - val_accuracy: 0.9120
# Epoch 84/100
# 3500/3500 [==============================] - 462s 132ms/step - loss: 0.3334 - accuracy: 0.9423 - val_loss: 0.4403 - val_accuracy: 0.9100
# Epoch 85/100
# 3500/3500 [==============================] - 463s 132ms/step - loss: 0.3159 - accuracy: 0.9506 - val_loss: 0.6141 - val_accuracy: 0.8520
# Epoch 86/100
# 3500/3500 [==============================] - 461s 132ms/step - loss: 0.3327 - accuracy: 0.9463 - val_loss: 0.4624 - val_accuracy: 0.8980
# Epoch 87/100
# 3500/3500 [==============================] - 462s 132ms/step - loss: 0.3211 - accuracy: 0.9480 - val_loss: 0.4244 - val_accuracy: 0.9160
# Epoch 88/100
# 3500/3500 [==============================] - 460s 131ms/step - loss: 0.3208 - accuracy: 0.9489 - val_loss: 0.4973 - val_accuracy: 0.8740
# Epoch 89/100
# 3500/3500 [==============================] - 467s 133ms/step - loss: 0.3128 - accuracy: 0.9529 - val_loss: 0.4804 - val_accuracy: 0.9020
# Epoch 90/100
# 3500/3500 [==============================] - 461s 132ms/step - loss: 0.3347 - accuracy: 0.9429 - val_loss: 0.4340 - val_accuracy: 0.9100
# Epoch 91/100
# 3500/3500 [==============================] - 463s 132ms/step - loss: 0.3290 - accuracy: 0.9474 - val_loss: 0.4354 - val_accuracy: 0.8980
# Epoch 92/100
# 3500/3500 [==============================] - 463s 132ms/step - loss: 0.3142 - accuracy: 0.9514 - val_loss: 0.4010 - val_accuracy: 0.9140
# Epoch 93/100
# 3500/3500 [==============================] - 459s 131ms/step - loss: 0.3122 - accuracy: 0.9529 - val_loss: 0.4491 - val_accuracy: 0.9160
# Epoch 94/100
# 3500/3500 [==============================] - 462s 132ms/step - loss: 0.3213 - accuracy: 0.9494 - val_loss: 0.4270 - val_accuracy: 0.9100
# Epoch 95/100
# 3500/3500 [==============================] - 461s 132ms/step - loss: 0.3099 - accuracy: 0.9537 - val_loss: 0.4717 - val_accuracy: 0.8980
# Epoch 96/100
# 1910/3500 [===============>..............] - ETA: 3:20 - loss: 0.3016 - accuracy: 0.9529

# %%
model.save("model_augmented.h5")
